# %%
import os
import fnmatch

# Computation
import numpy as np
from math import pi, log, sqrt

# Visualization
import imageio
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from astropy.io import fits

# Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Define data paths
DR2_path = "/data/astronomy-big-data/bc96e9620e41b9aba98292d37b5eec24/LoTSS_DR2/"
mosaic_path = "/data/astronomy-big-data/bc96e9620e41b9aba98292d37b5eec24/LoTSS_DR2_mosaic/"
writeable = "/data/astronomy-big-data/bc96e9620e41b9aba98292d37b5eec24/LoTSS_DR2_writable/"
IMAGE_PATH = 'mosaic_images'

# %% [markdown]
# # Load catalogue

# %%
CATALOGUE_FILE = "/data/astronomy-big-data/bc96e9620e41b9aba98292d37b5eec24/LoTSS_DR2_writable/catalogue_v5.3.csv.tar.gz"
HEADER_FILE = "/data/astronomy-big-data/bc96e9620e41b9aba98292d37b5eec24/LoTSS_DR2_writable/catalogue_v5.3_header.csv"

header = open(HEADER_FILE, 'r').readline()[:-1].split(',')
catalogue = pd.read_csv(CATALOGUE_FILE, sep=',', names=header)
catalogue = catalogue[(catalogue["overlap"] == 0) | (catalogue["overlap"] == 2)]
catalogue.tail()
# Out:
#                    label total_pixels x_pixels y_pixels integrated_intensity  \
# 2287874.0  P198+57_11003           39        8        6             0.522666
# 2287875.0  P198+57_11004           20        7        4             0.204829
# 2287876.0  P198+57_11005           30        7        6              0.32241
# 2287877.0  P198+57_11006           36        9        5             0.387224
# 2287878.0  P198+57_11007           48        9        7             0.911663
#
#           brightest_pixel brightest_pixel_x brightest_pixel_y  \
# 2287874.0     0.000566274              4090              8686
# 2287875.0     0.000356476              4832              8686
# 2287876.0     0.000377613              4759              8690
# 2287877.0     0.000350652              4219              8692
# 2287878.0      0.00113728              4517              8696
#
#           brightest_pixel_RA brightest_pixel_DEC  ... fit_y_axis  fit_theta  \
# 2287874.0            198.842             59.1766  ...    1.70811  -0.122944
# 2287875.0            198.239             59.1762  ...    1.20289  0.0320175
# 2287876.0            198.298              59.178  ...     2.4241      2.335
# 2287877.0            198.737             59.1792  ...    1.37658  0.0505499
# 2287878.0            198.495             59.1809  ...    1.67576  -0.170095
#
#           deconv_x  deconv_y integrated_intensity_fit ratio_residual   mosaic  \
# 2287874.0  4.06405  0.422976                 0.531733      0.0555658  P198+57
# 2287875.0  5.54893         0                 0.209438        0.12552  P198+57
# 2287876.0        0   4.07245                 0.331345       0.105084  P198+57
# 2287877.0  10.6434         0                 0.392656       0.107348  P198+57
# 2287878.0   2.3644         0                 0.930343      0.0346854  P198+57
#
#           object mosaic_id overlap
# 2287874.0  11003       154       2
# 2287875.0  11004       154       0
# 2287876.0  11005       154       0
# 2287877.0  11006       154       2
# 2287878.0  11007       154       2
#
# [5 rows x 29 columns]

# %% [markdown]
# # Check source

# %%
def crop(r, num_pxl):
    file = ''.join(fnmatch.filter(os.listdir(mosaic_path), r['mosaic'] + '*.fits'))
    hdul = fits.open(os.path.join(mosaic_path, file))
    data = hdul[0].data
    
    img_file = ''.join(fnmatch.filter(os.listdir(IMAGE_PATH), r['mosaic'] + '*.png'))
    r_img = imageio.imread(os.path.join(IMAGE_PATH, img_file))

    w, h = r_img.shape[:2]
    x = r['brightest_pixel_x']
    y = r['brightest_pixel_y']
    
    left = int(x - num_pxl if x - num_pxl > 0 else x - 1)
    top = int(y - num_pxl if y - num_pxl > 0 else y - 1)
    right = int(x + num_pxl if x + num_pxl < w else w)
    bottom = int(y + num_pxl if y + num_pxl < h else h)
    
    
    r_crop = r_img[top:bottom, left:right]
    # cmap = sources.make_cmap(random_state=12345)
    d_crop = data[top:bottom, left:right]
    return d_crop, r_crop


def getImgs(rows):
    fig, ax = plt.subplots(len(rows), 2, figsize=(15,10))
    num_pxl = np.amax(np.array([rows['x_pixels'].values, rows['y_pixels'].values])) + 15
    
    for (i, row) in enumerate(rows.iterrows()):
        d_crop, r_crop = crop(row[1], num_pxl)
        
        # Source
        ax[i,0].imshow(r_crop) # , cmap=cmap)
        ax[i,0].scatter(r_crop.shape[0]// 2, r_crop.shape[1] // 2, s=4, c='red')
        
        # Data
        ax[i,1].imshow(d_crop, origin='upper')
        ax[i,1].scatter(d_crop.shape[0]// 2, d_crop.shape[1] // 2, s=4, c='red')
    
    plt.show()
    print('-')*50

# %% [markdown]
# # Check random source

# %% [markdown]
# # Check Overlapping sources

# %%
# Load overlapping sources
overlaps = []
with open('../2.Overlap/overlap_pairs.csv', 'r') as infile:
    for line in infile:
        overlaps.append(np.array([pair.split(', ') for pair in line[2:-3].split('), (')], dtype=int))        

overlaps[:5]
# Out:
# [array([[  64, 9534],
#         [ 103, 1082],
#         [ 210, 8926],
#         [ 181, 1527]]),
#  array([[   44,  2378],
#         [  122, 11348]]),
#  array([[  44,  298],
#         [ 122, 8629]]),
#  array([[  56, 6134],
#         [ 164, 3486]]),
#  array([[    5, 12609],
#         [  104,  4342],
#         [  191,  4321]])]

# %%
m1, o1 = overlaps[0][0]
m2, o2 = overlaps[0][1]

overlaps = catalogue[((catalogue["mosaic_id"] == m1) & (catalogue["object"] == o1)) | 
                     ((catalogue["mosaic_id"] == m2) & (catalogue["object"] == o2))]
overlaps.head()
# Out:
#                 label total_pixels x_pixels y_pixels integrated_intensity  \
# 1102660  P182+55_1082           16        6        4             0.171571
# 1353550  P240+53_9534           26        6        6             0.384008
#
#         brightest_pixel brightest_pixel_x brightest_pixel_y  \
# 1102660     0.000314073              1626              1456
# 1353550     0.000578112              2317              8560
#
#         brightest_pixel_RA brightest_pixel_DEC  ... fit_y_axis fit_theta  \
# 1102660            184.442             53.5835  ...    1.01817   -0.2476
# 1353550            242.106             54.2201  ...    1.45422  0.337148
#
#         deconv_x deconv_y integrated_intensity_fit ratio_residual   mosaic  \
# 1102660  3.45628        0                 0.176839       0.149126  P182+55
# 1353550  2.12537        0                  0.39503      0.0837297  P240+53
#
#         object mosaic_id overlap
# 1102660   1082       103       0
# 1353550   9534        64       0
#
# [2 rows x 29 columns]

# %%
getImgs(overlaps)
# Out:
# 0
# label                       P182+55_1082
# total_pixels                          16
# x_pixels                               6
# y_pixels                               4
# integrated_intensity            0.171571
# brightest_pixel              0.000314073
# brightest_pixel_x                   1626
# brightest_pixel_y                   1456
# brightest_pixel_RA               184.442
# brightest_pixel_DEC              53.5835
# center_of_mass_x                 1626.71
# center_of_mass_y                 1455.64
# center_of_mass_RA                184.442
# center_of_mass_DEC               53.5833
# center_of_gaus_fit_x             1626.83
# center_of_gaus_fit_y             1455.65
# center_of_gaus_fit_RA            184.442
# center_of_gaus_fit_DEC           53.5833
# fit_x_axis                       2.24492
# fit_y_axis                       1.01817
# fit_theta                        -0.2476
# deconv_x                         3.45628
# deconv_y                               0
# integrated_intensity_fit        0.176839
# ratio_residual                  0.149126
# mosaic                           P182+55
# object                              1082
# mosaic_id                            103
# overlap                                0
# Name: 1102660, dtype: object
# 1
# label                       P240+53_9534
# total_pixels                          26
# x_pixels                               6
# y_pixels                               6
# integrated_intensity            0.384008
# brightest_pixel              0.000578112
# brightest_pixel_x                   2317
# brightest_pixel_y                   8560
# brightest_pixel_RA               242.106
# brightest_pixel_DEC              54.2201
# center_of_mass_x                 2317.42
# center_of_mass_y                  8560.2
# center_of_mass_RA                242.106
# center_of_mass_DEC               54.2202
# center_of_gaus_fit_x             2317.36
# center_of_gaus_fit_y             8560.17
# center_of_gaus_fit_RA            242.106
# center_of_gaus_fit_DEC           54.2202
# fit_x_axis                       1.92354
# fit_y_axis                       1.45422
# fit_theta                       0.337148
# deconv_x                         2.12537
# deconv_y                               0
# integrated_intensity_fit         0.39503
# ratio_residual                 0.0837297
# mosaic                           P240+53
# object                              9534
# mosaic_id                             64
# overlap                                0
# Name: 1353550, dtype: object
# -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-23b4cb917e24> in <module>
# ----> 1 getImgs(overlaps)
#
# <ipython-input-62-541b47bb4ce8> in getImgs(rows)
#      41
#      42     plt.show()
# ---> 43     print('-')*50
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %% [markdown]
# # Check Artifact

# %%
# Soon TM
